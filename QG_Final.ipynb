# %%
# !pip install sklearn-crfsuite
# Out:
# ...
#      |████████████████████████████████| 747kB 14.4MB/s
# ...

# %%
# !pip install pntl
# Out:
# ...
#      |████████████████████████████████| 2.5MB 16.1MB/s
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/question-answer-generation-master
# Out:
# /content/drive/.shortcut-targets-by-id/1BverPqPXJYcTUdkFvPsY8pD5kxIzqd98/question-answer-generation-master

# %%
# %cd QuestionGeneration
# Out:
# /content/drive/.shortcut-targets-by-id/1BverPqPXJYcTUdkFvPsY8pD5kxIzqd98/question-answer-generation-master/QuestionGeneration

# %%
import os
os.environ['STANFORD_PARSER'] = 'lib'
os.environ['STANFORD_MODELS'] = 'lib'

# %%
# !pip install py4j
# Out:
# ...
#      |████████████████████████████████| 204kB 14.1MB/s
# ...

# %%
from app import QuestionGenerator

# %%
import json

data = []
with open('dataset/SQuAD/train-v2.0.json') as f:
    json_data = json.load(f)['data']

    for i in range(len(json_data)):
        json_data_i = json_data[i]['paragraphs']
        
        for j in range(1):
            paragraph = json_data_i[j]['context']
            
            data.append(paragraph)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# %cd lib
# Out:
# /content/drive/.shortcut-targets-by-id/1BverPqPXJYcTUdkFvPsY8pD5kxIzqd98/question-answer-generation-master/QuestionGeneration/lib

# %%
# !netstat -ano | findstr :9000
# Out:
# /bin/bash: netstat: command not found
# /bin/bash: findstr: command not found

# %%
# !java -cp stanford-postagger.jar edu.stanford.nlp.tagger.maxent.MaxentTaggerServer -model models/english-left3words-distsim.tagger -port 8889
# Out:
# Loading default properties from tagger models/english-left3words-distsim.tagger
# Loading POS tagger from models/english-left3words-distsim.tagger ... done [1.3 sec].

# %%
import pprint
import random

pp = pprint.PrettyPrinter(indent=4)
random.seed(13515065)

for _ in range(3):
    i = random.randint(0, len(data))
    print(data[i])
    qg = QuestionGenerator(data[i])
    questions = qg.process(top_sentences=2)
    
    print("Paragraph: ", data[i])
    for q in questions:
        pp.pprint(q)
    print()
# Out:
# In the Pre-Modern era, many people's sense of self and purpose was often expressed via a faith in some form of deity, be that in a single God or in many gods. Pre-modern cultures have not been thought of creating a sense of distinct individuality, though. Religious officials, who often held positions of power, were the spiritual intermediaries to the common person. It was only through these intermediaries that the general masses had access to the divine. Tradition was sacred to ancient cultures and was unchanging and the social order of ceremony and morals in a culture could be strictly enforced.
# [Errno 111] Connection refused
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-60a52ffbc1cf> in <module>()
#       9     print(data[i])
#      10     qg = QuestionGenerator(data[i])
# ---> 11     questions = qg.process(top_sentences=2)
#      12
# ...
